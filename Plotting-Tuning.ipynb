# %%
import matplotlib as plb
import numpy as np
import pickle
import time
import random
from random import uniform

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn import preprocessing

from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
from sklearn.metrics import f1_score
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import log_loss
from sklearn.metrics import jaccard_score
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.datasets import make_classification
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
import der_snr
from PyAstronomy import pyasl
import io
#from astropy.io import fits
import skmultilearn
from skmultilearn.adapt import MLkNN
from sklearn.cluster import DBSCAN 
from sklearn.datasets.samples_generator import make_blobs 
from sklearn.preprocessing import StandardScaler 

from sklearn import manifold, datasets 
from sklearn.cluster import AgglomerativeClustering 
from scipy.spatial import distance_matrix 
from sklearn.cluster import KMeans 
from sklearn.preprocessing import MinMaxScaler
from sklearn import linear_model

from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

import h5py
from testCases_v4a import *
from dnn_utils_v2 import sigmoid, sigmoid_backward, relu, relu_backward

from PIL import Image
from scipy import ndimage

import tensorflow as tf 
from tensorflow.python.framework import ops
from cnn_utils import *
from scipy import interpolate
import keras
from keras.utils import to_categorical

from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model

import keras.backend as K
K.set_image_data_format('channels_last')
from sklearn.svm import LinearSVR

from sklearn.datasets import make_regression
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.multioutput import RegressorChain

from sklearn.metrics import accuracy_score

from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

from keras.utils import plot_model
from keras.layers import Input
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import LSTM

import tensorflow as tf
#from tensorflow import keras
#import keras
from keras.models import Sequential
from keras.layers import Dense
#from tensorflow.keras import layers
import linecache
import functools
import os
from pylab import *
import subprocess
import sys
from numpy import linalg as LA
#from astropy.stats import sigma_clip as sgc 
import pylab as p
# %matplotlib inline
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # Activation plot

# %%
data=np.loadtxt("Evaluation/Evaluation_activation-epoch100",dtype=str)
label=data[:,0]
eval_train_teff=np.array(data[:,1]).astype(np.float)
eval_test_teff=np.array(data[:,2]).astype(np.float)
eval_obs_teff=np.array(data[:,3]).astype(np.float)
eval_obs2_teff=np.array(data[:,4]).astype(np.float)
eval_train_logg=np.array(data[:,5]).astype(np.float)
eval_test_logg=np.array(data[:,6]).astype(np.float)
eval_obs_logg=np.array(data[:,7]).astype(np.float)
eval_obs2_logg=np.array(data[:,8]).astype(np.float)
eval_train_vrot=np.array(data[:,9]).astype(np.float)
eval_test_vrot=np.array(data[:,10]).astype(np.float)
eval_obs_vrot=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot=np.array(data[:,12]).astype(np.float)
eval_train_meta=np.array(data[:,13]).astype(np.float)
eval_test_meta=np.array(data[:,14]).astype(np.float)
eval_obs_meta=np.array(data[:,15]).astype(np.float)
eval_obs2_meta=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_activation-epoch500",dtype=str)
eval_train_teff500=np.array(data[:,1]).astype(np.float)
eval_test_teff500=np.array(data[:,2]).astype(np.float)
eval_obs_teff500=np.array(data[:,3]).astype(np.float)
eval_obs2_teff500=np.array(data[:,4]).astype(np.float)
eval_train_logg500=np.array(data[:,5]).astype(np.float)
eval_test_logg500=np.array(data[:,6]).astype(np.float)
eval_obs_logg500=np.array(data[:,7]).astype(np.float)
eval_obs2_logg500=np.array(data[:,8]).astype(np.float)
eval_train_vrot500=np.array(data[:,9]).astype(np.float)
eval_test_vrot500=np.array(data[:,10]).astype(np.float)
eval_obs_vrot500=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot500=np.array(data[:,12]).astype(np.float)
eval_train_meta500=np.array(data[:,13]).astype(np.float)
eval_test_meta500=np.array(data[:,14]).astype(np.float)
eval_obs_meta500=np.array(data[:,15]).astype(np.float)
eval_obs2_meta500=np.array(data[:,16]).astype(np.float)

data=np.loadtxt("Evaluation/Evaluation_activation-epoch1000",dtype=str)
eval_train_teff1000=np.array(data[:,1]).astype(np.float)
eval_test_teff1000=np.array(data[:,2]).astype(np.float)
eval_obs_teff1000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff1000=np.array(data[:,4]).astype(np.float)
eval_train_logg1000=np.array(data[:,5]).astype(np.float)
eval_test_logg1000=np.array(data[:,6]).astype(np.float)
eval_obs_logg1000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg1000=np.array(data[:,8]).astype(np.float)
eval_train_vrot1000=np.array(data[:,9]).astype(np.float)
eval_test_vrot1000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot1000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot1000=np.array(data[:,12]).astype(np.float)
eval_train_meta1000=np.array(data[:,13]).astype(np.float)
eval_test_meta1000=np.array(data[:,14]).astype(np.float)
eval_obs_meta1000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta1000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_activation-epoch2000",dtype=str)
eval_train_teff2000=np.array(data[:,1]).astype(np.float)
eval_test_teff2000=np.array(data[:,2]).astype(np.float)
eval_obs_teff2000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff2000=np.array(data[:,4]).astype(np.float)
eval_train_logg2000=np.array(data[:,5]).astype(np.float)
eval_test_logg2000=np.array(data[:,6]).astype(np.float)
eval_obs_logg2000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg2000=np.array(data[:,8]).astype(np.float)
eval_train_vrot2000=np.array(data[:,9]).astype(np.float)
eval_test_vrot2000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot2000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot2000=np.array(data[:,12]).astype(np.float)
eval_train_meta2000=np.array(data[:,13]).astype(np.float)
eval_test_meta2000=np.array(data[:,14]).astype(np.float)
eval_obs_meta2000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta2000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_activation-epoch3000",dtype=str)
eval_train_teff3000=np.array(data[:,1]).astype(np.float)
eval_test_teff3000=np.array(data[:,2]).astype(np.float)
eval_obs_teff3000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff3000=np.array(data[:,4]).astype(np.float)
eval_train_logg3000=np.array(data[:,5]).astype(np.float)
eval_test_logg3000=np.array(data[:,6]).astype(np.float)
eval_obs_logg3000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg3000=np.array(data[:,8]).astype(np.float)
eval_train_vrot3000=np.array(data[:,9]).astype(np.float)
eval_test_vrot3000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot3000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot3000=np.array(data[:,12]).astype(np.float)
eval_train_meta3000=np.array(data[:,13]).astype(np.float)
eval_test_meta3000=np.array(data[:,14]).astype(np.float)
eval_obs_meta3000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta3000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_activation-epoch4000",dtype=str)
eval_train_teff4000=np.array(data[:,1]).astype(np.float)
eval_test_teff4000=np.array(data[:,2]).astype(np.float)
eval_obs_teff4000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff4000=np.array(data[:,4]).astype(np.float)
eval_train_logg4000=np.array(data[:,5]).astype(np.float)
eval_test_logg4000=np.array(data[:,6]).astype(np.float)
eval_obs_logg4000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg4000=np.array(data[:,8]).astype(np.float)
eval_train_vrot4000=np.array(data[:,9]).astype(np.float)
eval_test_vrot4000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot4000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot4000=np.array(data[:,12]).astype(np.float)
eval_train_meta4000=np.array(data[:,13]).astype(np.float)
eval_test_meta4000=np.array(data[:,14]).astype(np.float)
eval_obs_meta4000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta4000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_activation-epoch5000",dtype=str)
eval_train_teff5000=np.array(data[:,1]).astype(np.float)
eval_test_teff5000=np.array(data[:,2]).astype(np.float)
eval_obs_teff5000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff5000=np.array(data[:,4]).astype(np.float)
eval_train_logg5000=np.array(data[:,5]).astype(np.float)
eval_test_logg5000=np.array(data[:,6]).astype(np.float)
eval_obs_logg5000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg5000=np.array(data[:,8]).astype(np.float)
eval_train_vrot5000=np.array(data[:,9]).astype(np.float)
eval_test_vrot5000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot5000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot5000=np.array(data[:,12]).astype(np.float)
eval_train_meta5000=np.array(data[:,13]).astype(np.float)
eval_test_meta5000=np.array(data[:,14]).astype(np.float)
eval_obs_meta5000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta5000=np.array(data[:,16]).astype(np.float)

Teff=[eval_obs2_teff,eval_obs2_teff500,eval_obs2_teff1000,eval_obs2_teff2000,eval_obs2_teff3000,eval_obs2_teff4000,eval_obs2_teff5000]

logg=[eval_obs2_logg,eval_obs2_logg500,eval_obs2_logg1000,eval_obs2_logg2000,eval_obs2_logg3000,eval_obs2_logg4000,eval_obs2_logg5000]


vrot=[eval_obs2_vrot,eval_obs2_vrot500,eval_obs2_vrot1000,eval_obs2_vrot2000,eval_obs2_vrot3000,eval_obs2_vrot4000,eval_obs2_vrot5000]

meta=[eval_obs2_meta,eval_obs2_meta500,eval_obs2_meta1000,eval_obs2_meta2000,eval_obs2_meta3000,eval_obs2_meta4000,eval_obs2_meta5000]


Teff=np.array(Teff).astype(np.float).max()
logg=np.array(logg).astype(np.float).max()
vrot=np.array(vrot).astype(np.float).max()
meta=np.array(meta).astype(np.float).max()

# %% [markdown]
# ## Teff

# %%
#plot(label, eval_train_teff/eval_train_teff.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_teff/eval_test_teff.max(),'b-o',label='Validation',color='b')
#plot(label, eval_obs_teff/eval_obs_teff.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_teff/Teff,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_teff500/Teff,'k--s',label='Observation-500')
plot(label, eval_obs2_teff1000/Teff,'k--^',label='Observation-1000')
plot(label, eval_obs2_teff2000/Teff,'k-->',label='Observation-2000')
plot(label, eval_obs2_teff3000/Teff,'k--<',label='Observation-3000')
plot(label, eval_obs2_teff4000/Teff,'k--*',label='Observation-4000')
plot(label, eval_obs2_teff5000/Teff,'k--x',label='Observation-5000')



plt.xlabel("Activation function",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
plt.legend(loc='best')

plt.text(0.3, 0.95, '$T_{eff}$',  fontsize=15,color='k')
plt.savefig("Figures/Teff-Activation.png",dpi=300)
plt.savefig("Figures/Teff-Activation.pdf")

# %% [markdown]
# ##  logg

# %%
#plot(label, eval_train_logg/eval_train_logg.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_logg/eval_test_logg.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_logg/eval_obs_logg.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_logg/logg,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_logg500/logg,'k--s',label='Observation-500')
plot(label, eval_obs2_logg1000/logg,'k--^',label='Observation-1000')
plot(label, eval_obs2_logg2000/logg,'k-->',label='Observation-2000')
plot(label, eval_obs2_logg3000/logg,'k--<',label='Observation-3000')
plot(label, eval_obs2_logg4000/logg,'k--*',label='Observation-4000')
plot(label, eval_obs2_logg5000/logg,'k--x',label='Observation-5000')







plt.xlabel("Activation function",fontsize=14)


plt.ylabel("Relative error w.r.t Max",fontsize=14)
plt.legend(loc='best')

plt.text(0.3, 0.35, '$\log g$',  fontsize=15,color='k')

plt.savefig("Figures/Logg-Activation.png",dpi=300)
plt.savefig("Figures/Logg-Activation.pdf")

# %% [markdown]
# ## Vsini

# %%
#plot(label, eval_train_vrot/eval_train_vrot.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_vrot/eval_test_vrot.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_vrot/eval_obs_vrot.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_vrot/vrot,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_vrot500/vrot,'k--s',label='Observation-500')
plot(label, eval_obs2_vrot1000/vrot,'k--^',label='Observation-1000')
plot(label, eval_obs2_vrot2000/vrot,'k-->',label='Observation-2000')
plot(label, eval_obs2_vrot3000/vrot,'k--<',label='Observation-3000')
plot(label, eval_obs2_vrot4000/vrot,'k--*',label='Observation-4000')
plot(label, eval_obs2_vrot5000/vrot,'k--x',label='Observation-5000')


plt.xlabel("Activation function",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
plt.legend()
plt.text(0.3, 0.95, '$v\sin i$',  fontsize=15,color='k')
plt.savefig("Figures/Vrot-Activation.png",dpi=300)
plt.savefig("Figures/Vrot-Activation.pdf")

# %% [markdown]
# ## Meta

# %%
#plot(label, eval_train_meta/eval_train_meta.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_meta/eval_test_meta.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_meta/eval_obs_meta.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_meta/meta,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_meta500/meta,'k--s',label='Observation-500')
plot(label, eval_obs2_meta1000/meta,'k--^',label='Observation-1000')
plot(label, eval_obs2_meta2000/meta,'k-->',label='Observation-2000')
plot(label, eval_obs2_meta3000/meta,'k--<',label='Observation-3000')
plot(label, eval_obs2_meta4000/meta,'k--*',label='Observation-4000')
plot(label, eval_obs2_meta5000/meta,'k--x',label='Observation-5000')

plt.xlabel("Activation function",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
plt.legend()
plt.text(0.3, 0.35, '[X/H]',  fontsize=15,color='k')
plt.savefig("Figures/Meta-Activation.png",dpi=300)
plt.savefig("Figures/Meta-Activation.pdf")

# %% [markdown]
# # Optimizer

# %%
data=np.loadtxt("Evaluation/Evaluation_Optimizer-epoch100",dtype=str)
label=data[:,0]
eval_train_teff=np.array(data[:,1]).astype(np.float)
eval_test_teff=np.array(data[:,2]).astype(np.float)
eval_obs_teff=np.array(data[:,3]).astype(np.float)
eval_obs2_teff=np.array(data[:,4]).astype(np.float)
eval_train_logg=np.array(data[:,5]).astype(np.float)
eval_test_logg=np.array(data[:,6]).astype(np.float)
eval_obs_logg=np.array(data[:,7]).astype(np.float)
eval_obs2_logg=np.array(data[:,8]).astype(np.float)
eval_train_vrot=np.array(data[:,9]).astype(np.float)
eval_test_vrot=np.array(data[:,10]).astype(np.float)
eval_obs_vrot=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot=np.array(data[:,12]).astype(np.float)
eval_train_meta=np.array(data[:,13]).astype(np.float)
eval_test_meta=np.array(data[:,14]).astype(np.float)
eval_obs_meta=np.array(data[:,15]).astype(np.float)
eval_obs2_meta=np.array(data[:,16]).astype(np.float)


data=np.loadtxt("Evaluation/Evaluation_Optimizer-epoch500",dtype=str)
eval_train_teff500=np.array(data[:,1]).astype(np.float)
eval_test_teff500=np.array(data[:,2]).astype(np.float)
eval_obs_teff500=np.array(data[:,3]).astype(np.float)
eval_obs2_teff500=np.array(data[:,4]).astype(np.float)
eval_train_logg500=np.array(data[:,5]).astype(np.float)
eval_test_logg500=np.array(data[:,6]).astype(np.float)
eval_obs_logg500=np.array(data[:,7]).astype(np.float)
eval_obs2_logg500=np.array(data[:,8]).astype(np.float)
eval_train_vrot500=np.array(data[:,9]).astype(np.float)
eval_test_vrot500=np.array(data[:,10]).astype(np.float)
eval_obs_vrot500=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot500=np.array(data[:,12]).astype(np.float)
eval_train_meta500=np.array(data[:,13]).astype(np.float)
eval_test_meta500=np.array(data[:,14]).astype(np.float)
eval_obs_meta500=np.array(data[:,15]).astype(np.float)
eval_obs2_meta500=np.array(data[:,16]).astype(np.float)

data=np.loadtxt("Evaluation/Evaluation_Optimizer-epoch1000",dtype=str)
eval_train_teff1000=np.array(data[:,1]).astype(np.float)
eval_test_teff1000=np.array(data[:,2]).astype(np.float)
eval_obs_teff1000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff1000=np.array(data[:,4]).astype(np.float)
eval_train_logg1000=np.array(data[:,5]).astype(np.float)
eval_test_logg1000=np.array(data[:,6]).astype(np.float)
eval_obs_logg1000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg1000=np.array(data[:,8]).astype(np.float)
eval_train_vrot1000=np.array(data[:,9]).astype(np.float)
eval_test_vrot1000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot1000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot1000=np.array(data[:,12]).astype(np.float)
eval_train_meta1000=np.array(data[:,13]).astype(np.float)
eval_test_meta1000=np.array(data[:,14]).astype(np.float)
eval_obs_meta1000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta1000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_Optimizer-epoch2000",dtype=str)
eval_train_teff2000=np.array(data[:,1]).astype(np.float)
eval_test_teff2000=np.array(data[:,2]).astype(np.float)
eval_obs_teff2000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff2000=np.array(data[:,4]).astype(np.float)
eval_train_logg2000=np.array(data[:,5]).astype(np.float)
eval_test_logg2000=np.array(data[:,6]).astype(np.float)
eval_obs_logg2000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg2000=np.array(data[:,8]).astype(np.float)
eval_train_vrot2000=np.array(data[:,9]).astype(np.float)
eval_test_vrot2000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot2000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot2000=np.array(data[:,12]).astype(np.float)
eval_train_meta2000=np.array(data[:,13]).astype(np.float)
eval_test_meta2000=np.array(data[:,14]).astype(np.float)
eval_obs_meta2000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta2000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_Optimizer-epoch3000",dtype=str)
eval_train_teff3000=np.array(data[:,1]).astype(np.float)
eval_test_teff3000=np.array(data[:,2]).astype(np.float)
eval_obs_teff3000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff3000=np.array(data[:,4]).astype(np.float)
eval_train_logg3000=np.array(data[:,5]).astype(np.float)
eval_test_logg3000=np.array(data[:,6]).astype(np.float)
eval_obs_logg3000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg3000=np.array(data[:,8]).astype(np.float)
eval_train_vrot3000=np.array(data[:,9]).astype(np.float)
eval_test_vrot3000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot3000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot3000=np.array(data[:,12]).astype(np.float)
eval_train_meta3000=np.array(data[:,13]).astype(np.float)
eval_test_meta3000=np.array(data[:,14]).astype(np.float)
eval_obs_meta3000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta3000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_Optimizer-epoch4000",dtype=str)
eval_train_teff4000=np.array(data[:,1]).astype(np.float)
eval_test_teff4000=np.array(data[:,2]).astype(np.float)
eval_obs_teff4000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff4000=np.array(data[:,4]).astype(np.float)
eval_train_logg4000=np.array(data[:,5]).astype(np.float)
eval_test_logg4000=np.array(data[:,6]).astype(np.float)
eval_obs_logg4000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg4000=np.array(data[:,8]).astype(np.float)
eval_train_vrot4000=np.array(data[:,9]).astype(np.float)
eval_test_vrot4000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot4000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot4000=np.array(data[:,12]).astype(np.float)
eval_train_meta4000=np.array(data[:,13]).astype(np.float)
eval_test_meta4000=np.array(data[:,14]).astype(np.float)
eval_obs_meta4000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta4000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_Optimizer-epoch5000",dtype=str)
eval_train_teff5000=np.array(data[:,1]).astype(np.float)
eval_test_teff5000=np.array(data[:,2]).astype(np.float)
eval_obs_teff5000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff5000=np.array(data[:,4]).astype(np.float)
eval_train_logg5000=np.array(data[:,5]).astype(np.float)
eval_test_logg5000=np.array(data[:,6]).astype(np.float)
eval_obs_logg5000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg5000=np.array(data[:,8]).astype(np.float)
eval_train_vrot5000=np.array(data[:,9]).astype(np.float)
eval_test_vrot5000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot5000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot5000=np.array(data[:,12]).astype(np.float)
eval_train_meta5000=np.array(data[:,13]).astype(np.float)
eval_test_meta5000=np.array(data[:,14]).astype(np.float)
eval_obs_meta5000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta5000=np.array(data[:,16]).astype(np.float)

Teff=[eval_obs2_teff,eval_obs2_teff500,eval_obs2_teff1000,eval_obs2_teff2000,eval_obs2_teff3000,eval_obs2_teff4000,eval_obs2_teff5000]

logg=[eval_obs2_logg,eval_obs2_logg500,eval_obs2_logg1000,eval_obs2_logg2000,eval_obs2_logg3000,eval_obs2_logg4000,eval_obs2_logg5000]


vrot=[eval_obs2_vrot,eval_obs2_vrot500,eval_obs2_vrot1000,eval_obs2_vrot2000,eval_obs2_vrot3000,eval_obs2_vrot4000,eval_obs2_vrot5000]

meta=[eval_obs2_meta,eval_obs2_meta500,eval_obs2_meta1000,eval_obs2_meta2000,eval_obs2_meta3000,eval_obs2_meta4000,eval_obs2_meta5000]


Teff=np.array(Teff).astype(np.float).max()
logg=np.array(logg).astype(np.float).max()
vrot=np.array(vrot).astype(np.float).max()
meta=np.array(meta).astype(np.float).max()

# %%
#Teff
#plot(label, eval_train_teff/eval_train_teff.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_teff/eval_test_teff.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_teff/eval_obs_teff.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_teff/Teff,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_teff500/Teff,'k--s',label='Observation-500')

plot(label, eval_obs2_teff1000/Teff,'k--^',label='Observation-1000')
plot(label, eval_obs2_teff2000/Teff,'k-->',label='Observation-2000')
plot(label, eval_obs2_teff3000/Teff,'k--<',label='Observation-3000')
plot(label, eval_obs2_teff4000/Teff,'k--*',label='Observation-4000')
plot(label, eval_obs2_teff5000/Teff,'k--x',label='Observation-5000')


plt.xlabel("Optimizer",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$T_{eff}$',  fontsize=15,color='k')
plt.savefig("Figures/Teff-Opt.png",dpi=300)
plt.savefig("Figures/Teff-Opt.pdf")

# %%
#Logg
#plot(label, eval_train_logg/eval_train_logg.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_logg/eval_test_logg.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_logg/eval_obs_logg.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_logg/logg,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_logg500/logg,'k--s',label='Observation-500')
plot(label, eval_obs2_logg1000/logg,'k--^',label='Observation-1000')
plot(label, eval_obs2_logg2000/logg,'k-->',label='Observation-2000')
plot(label, eval_obs2_logg3000/logg,'k--<',label='Observation-3000')
plot(label, eval_obs2_logg4000/logg,'k--*',label='Observation-4000')
plot(label, eval_obs2_logg5000/logg,'k--x',label='Observation-5000')


plt.xlabel("Optimizer",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$\log g$',  fontsize=15,color='k')
plt.savefig("Figures/Logg-Opt.png",dpi=300)
plt.savefig("Figures/Logg-Opt.pdf")

# %%
#vsini
#plot(label, eval_train_vrot/eval_train_vrot.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_vrot/eval_test_vrot.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_vrot/eval_obs_vrot.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_vrot/vrot,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_vrot500/vrot,'k--s',label='Observation-500')
plot(label, eval_obs2_vrot1000/vrot,'k--^',label='Observation-1000')
plot(label, eval_obs2_vrot2000/vrot,'k-->',label='Observation-2000')
plot(label, eval_obs2_vrot3000/vrot,'k--<',label='Observation-3000')
plot(label, eval_obs2_vrot4000/vrot,'k--*',label='Observation-4000')
plot(label, eval_obs2_vrot5000/vrot,'k--x',label='Observation-5000')


plt.xlabel("Optimizer",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend(loc=1)
#plt.text(0.3, 0.95, '$v\sin i$',  fontsize=15,color='k')
plt.savefig("Figures/Vrot-Opt.png",dpi=300)
plt.savefig("Figures/Vrot-Opt.pdf")

# %%
#Meta
#plot(label, eval_train_meta/eval_train_meta.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_meta/eval_test_meta.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_meta/eval_obs_meta.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_meta/meta,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_meta500/meta,'k--s',label='Observation-500')
plot(label, eval_obs2_meta1000/meta,'k--^',label='Observation-1000')
plot(label, eval_obs2_meta2000/meta,'k-->',label='Observation-2000')
plot(label, eval_obs2_meta3000/meta,'k--<',label='Observation-3000')
plot(label, eval_obs2_meta4000/meta,'k--*',label='Observation-4000')
plot(label, eval_obs2_meta5000/meta,'k--x',label='Observation-5000')


plt.xlabel("Optimizer",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '[X/H]',  fontsize=15,color='k')
plt.savefig("Figures/Meta-Opt.png",dpi=300)
plt.savefig("Figures/Meta-Opt.pdf")

# %% [markdown]
# # Kernel

# %%
data=np.loadtxt("Evaluation/Evaluation_kernel_initializer-epoch100",dtype=str)
label=data[:,0]
eval_train_teff=np.array(data[:,1]).astype(np.float)
eval_test_teff=np.array(data[:,2]).astype(np.float)
eval_obs_teff=np.array(data[:,3]).astype(np.float)
eval_obs2_teff=np.array(data[:,4]).astype(np.float)
eval_train_logg=np.array(data[:,5]).astype(np.float)
eval_test_logg=np.array(data[:,6]).astype(np.float)
eval_obs_logg=np.array(data[:,7]).astype(np.float)
eval_obs2_logg=np.array(data[:,8]).astype(np.float)
eval_train_vrot=np.array(data[:,9]).astype(np.float)
eval_test_vrot=np.array(data[:,10]).astype(np.float)
eval_obs_vrot=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot=np.array(data[:,12]).astype(np.float)
eval_train_meta=np.array(data[:,13]).astype(np.float)
eval_test_meta=np.array(data[:,14]).astype(np.float)
eval_obs_meta=np.array(data[:,15]).astype(np.float)
eval_obs2_meta=np.array(data[:,16]).astype(np.float)


data=np.loadtxt("Evaluation/Evaluation_kernel_initializer-epoch500",dtype=str)
eval_train_teff500=np.array(data[:,1]).astype(np.float)
eval_test_teff500=np.array(data[:,2]).astype(np.float)
eval_obs_teff500=np.array(data[:,3]).astype(np.float)
eval_obs2_teff500=np.array(data[:,4]).astype(np.float)
eval_train_logg500=np.array(data[:,5]).astype(np.float)
eval_test_logg500=np.array(data[:,6]).astype(np.float)
eval_obs_logg500=np.array(data[:,7]).astype(np.float)
eval_obs2_logg500=np.array(data[:,8]).astype(np.float)
eval_train_vrot500=np.array(data[:,9]).astype(np.float)
eval_test_vrot500=np.array(data[:,10]).astype(np.float)
eval_obs_vrot500=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot500=np.array(data[:,12]).astype(np.float)
eval_train_meta500=np.array(data[:,13]).astype(np.float)
eval_test_meta500=np.array(data[:,14]).astype(np.float)
eval_obs_meta500=np.array(data[:,15]).astype(np.float)
eval_obs2_meta500=np.array(data[:,16]).astype(np.float)

data=np.loadtxt("Evaluation/Evaluation_kernel_initializer-epoch1000",dtype=str)
eval_train_teff1000=np.array(data[:,1]).astype(np.float)
eval_test_teff1000=np.array(data[:,2]).astype(np.float)
eval_obs_teff1000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff1000=np.array(data[:,4]).astype(np.float)
eval_train_logg1000=np.array(data[:,5]).astype(np.float)
eval_test_logg1000=np.array(data[:,6]).astype(np.float)
eval_obs_logg1000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg1000=np.array(data[:,8]).astype(np.float)
eval_train_vrot1000=np.array(data[:,9]).astype(np.float)
eval_test_vrot1000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot1000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot1000=np.array(data[:,12]).astype(np.float)
eval_train_meta1000=np.array(data[:,13]).astype(np.float)
eval_test_meta1000=np.array(data[:,14]).astype(np.float)
eval_obs_meta1000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta1000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_kernel_initializer-epoch2000",dtype=str)
eval_train_teff2000=np.array(data[:,1]).astype(np.float)
eval_test_teff2000=np.array(data[:,2]).astype(np.float)
eval_obs_teff2000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff2000=np.array(data[:,4]).astype(np.float)
eval_train_logg2000=np.array(data[:,5]).astype(np.float)
eval_test_logg2000=np.array(data[:,6]).astype(np.float)
eval_obs_logg2000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg2000=np.array(data[:,8]).astype(np.float)
eval_train_vrot2000=np.array(data[:,9]).astype(np.float)
eval_test_vrot2000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot2000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot2000=np.array(data[:,12]).astype(np.float)
eval_train_meta2000=np.array(data[:,13]).astype(np.float)
eval_test_meta2000=np.array(data[:,14]).astype(np.float)
eval_obs_meta2000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta2000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_kernel_initializer-epoch3000",dtype=str)
eval_train_teff3000=np.array(data[:,1]).astype(np.float)
eval_test_teff3000=np.array(data[:,2]).astype(np.float)
eval_obs_teff3000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff3000=np.array(data[:,4]).astype(np.float)
eval_train_logg3000=np.array(data[:,5]).astype(np.float)
eval_test_logg3000=np.array(data[:,6]).astype(np.float)
eval_obs_logg3000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg3000=np.array(data[:,8]).astype(np.float)
eval_train_vrot3000=np.array(data[:,9]).astype(np.float)
eval_test_vrot3000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot3000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot3000=np.array(data[:,12]).astype(np.float)
eval_train_meta3000=np.array(data[:,13]).astype(np.float)
eval_test_meta3000=np.array(data[:,14]).astype(np.float)
eval_obs_meta3000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta3000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_kernel_initializer-epoch4000",dtype=str)
eval_train_teff4000=np.array(data[:,1]).astype(np.float)
eval_test_teff4000=np.array(data[:,2]).astype(np.float)
eval_obs_teff4000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff4000=np.array(data[:,4]).astype(np.float)
eval_train_logg4000=np.array(data[:,5]).astype(np.float)
eval_test_logg4000=np.array(data[:,6]).astype(np.float)
eval_obs_logg4000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg4000=np.array(data[:,8]).astype(np.float)
eval_train_vrot4000=np.array(data[:,9]).astype(np.float)
eval_test_vrot4000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot4000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot4000=np.array(data[:,12]).astype(np.float)
eval_train_meta4000=np.array(data[:,13]).astype(np.float)
eval_test_meta4000=np.array(data[:,14]).astype(np.float)
eval_obs_meta4000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta4000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_kernel_initializer-epoch5000",dtype=str)
eval_train_teff5000=np.array(data[:,1]).astype(np.float)
eval_test_teff5000=np.array(data[:,2]).astype(np.float)
eval_obs_teff5000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff5000=np.array(data[:,4]).astype(np.float)
eval_train_logg5000=np.array(data[:,5]).astype(np.float)
eval_test_logg5000=np.array(data[:,6]).astype(np.float)
eval_obs_logg5000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg5000=np.array(data[:,8]).astype(np.float)
eval_train_vrot5000=np.array(data[:,9]).astype(np.float)
eval_test_vrot5000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot5000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot5000=np.array(data[:,12]).astype(np.float)
eval_train_meta5000=np.array(data[:,13]).astype(np.float)
eval_test_meta5000=np.array(data[:,14]).astype(np.float)
eval_obs_meta5000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta5000=np.array(data[:,16]).astype(np.float)

Teff=[eval_obs2_teff,eval_obs2_teff500,eval_obs2_teff1000,eval_obs2_teff2000,eval_obs2_teff3000,eval_obs2_teff4000,eval_obs2_teff5000]

logg=[eval_obs2_logg,eval_obs2_logg500,eval_obs2_logg1000,eval_obs2_logg2000,eval_obs2_logg3000,eval_obs2_logg4000,eval_obs2_logg5000]


vrot=[eval_obs2_vrot,eval_obs2_vrot500,eval_obs2_vrot1000,eval_obs2_vrot2000,eval_obs2_vrot3000,eval_obs2_vrot4000,eval_obs2_vrot5000]

meta=[eval_obs2_meta,eval_obs2_meta500,eval_obs2_meta1000,eval_obs2_meta2000,eval_obs2_meta3000,eval_obs2_meta4000,eval_obs2_meta5000]


Teff=np.array(Teff).astype(np.float).max()
logg=np.array(logg).astype(np.float).max()
vrot=np.array(vrot).astype(np.float).max()
meta=np.array(meta).astype(np.float).max()

# %%
#Teff
#plot(label, eval_train_teff/eval_train_teff.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_teff/eval_test_teff.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_teff/eval_obs_teff.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_teff/Teff,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_teff500/Teff,'k--s',label='Observation-500')
plot(label, eval_obs2_teff1000/Teff,'k--^',label='Observation-1000')
plot(label, eval_obs2_teff2000/Teff,'k-->',label='Observation-2000')
plot(label, eval_obs2_teff3000/Teff,'k--<',label='Observation-3000')
plot(label, eval_obs2_teff4000/Teff,'k--*',label='Observation-4000')
plot(label, eval_obs2_teff5000/Teff,'k--x',label='Observation-5000')


plt.xlabel("Kernel",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
plt.xticks(rotation=90,fontsize=10)
#plt.text(0.3, 0.95, '$T_{eff}$',  fontsize=15,color='k')
plt.savefig("Figures/Teff-Kernel.png",dpi=300)
plt.savefig("Figures/Teff-Kernel.pdf")

# %%
#Logg
#plot(label, eval_train_logg/eval_train_logg.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_logg/eval_test_logg.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_logg/eval_obs_logg.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_logg/logg,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_logg500/logg,'k--s',label='Observation-500')
plot(label, eval_obs2_logg1000/logg,'k--^',label='Observation-1000')
plot(label, eval_obs2_logg2000/logg,'k-->',label='Observation-2000')
plot(label, eval_obs2_logg3000/logg,'k--<',label='Observation-3000')
plot(label, eval_obs2_logg4000/logg,'k--*',label='Observation-4000')
plot(label, eval_obs2_logg5000/logg,'k--x',label='Observation-5000')


plt.xlabel("Kernel",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
plt.xticks(rotation=90)

#plt.text(0.3, 0.95, '$\log g$',  fontsize=15,color='k')
plt.savefig("Figures/Logg-Kernel.png",dpi=300)
plt.savefig("Figures/Logg-Kernel.pdf")

# %%
#vsini
#plot(label, eval_train_vrot/eval_train_vrot.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_vrot/eval_test_vrot.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_vrot/eval_obs_vrot.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_vrot/vrot,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_vrot500/vrot,'k--s',label='Observation-500')
plot(label, eval_obs2_vrot1000/vrot,'k--^',label='Observation-1000')
plot(label, eval_obs2_vrot2000/vrot,'k-->',label='Observation-2000')
plot(label, eval_obs2_vrot3000/vrot,'k--<',label='Observation-3000')
plot(label, eval_obs2_vrot4000/vrot,'k--*',label='Observation-4000')
plot(label, eval_obs2_vrot5000/vrot,'k--x',label='Observation-5000')


plt.xlabel("Kernel",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
plt.xticks(rotation=90)

#plt.text(0.3, 0.95, '$v\sin i$',  fontsize=15,color='k')
plt.savefig("Figures/Vrot-Kernel.png",dpi=300)
plt.savefig("Figures/Vrot-Kernel.pdf")

# %%
#Meta
#plot(label, eval_train_meta/eval_train_meta.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_meta/eval_test_meta.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_meta/eval_obs_meta.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_meta/meta,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_meta500/meta,'k--s',label='Observation-500')
plot(label, eval_obs2_meta1000/meta,'k--^',label='Observation-1000')
plot(label, eval_obs2_meta2000/meta,'k-->',label='Observation-2000')
plot(label, eval_obs2_meta3000/meta,'k--<',label='Observation-3000')
plot(label, eval_obs2_meta4000/meta,'k--*',label='Observation-4000')
plot(label, eval_obs2_meta5000/meta,'k--x',label='Observation-5000')


plt.xlabel("Kernel",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
plt.xticks(rotation=90)

#plt.text(0.3, 0.95, '[X/H]',  fontsize=15,color='k')
plt.savefig("Figures/Meta-Kernel.png",dpi=300)
plt.savefig("Figures/Meta-Kernel.pdf")

# %% [markdown]
# # Epochs

# %%
data=np.loadtxt("Evaluation/Evaluation_Epochs",dtype=str)
label=data[:,0]
eval_train_teff=np.array(data[:,1]).astype(np.float)
eval_test_teff=np.array(data[:,2]).astype(np.float)
eval_obs_teff=np.array(data[:,3]).astype(np.float)
eval_obs2_teff=np.array(data[:,4]).astype(np.float)
eval_train_logg=np.array(data[:,5]).astype(np.float)
eval_test_logg=np.array(data[:,6]).astype(np.float)
eval_obs_logg=np.array(data[:,7]).astype(np.float)
eval_obs2_logg=np.array(data[:,8]).astype(np.float)
eval_train_vrot=np.array(data[:,9]).astype(np.float)
eval_test_vrot=np.array(data[:,10]).astype(np.float)
eval_obs_vrot=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot=np.array(data[:,12]).astype(np.float)
eval_train_meta=np.array(data[:,13]).astype(np.float)
eval_test_meta=np.array(data[:,14]).astype(np.float)
eval_obs_meta=np.array(data[:,15]).astype(np.float)
eval_obs2_meta=np.array(data[:,16]).astype(np.float)

# %%
#Teff
#plot(label, eval_train_teff/eval_train_teff.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_teff/eval_test_teff.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_teff/eval_obs_teff.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_teff/eval_obs2_teff.max(),'k--d',label='Observation',color='k')
plt.xlabel("# Epochs",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.05, 0.95, '$T_{eff}$',  fontsize=15,color='k')
plt.savefig("Figures/Teff-Epochs.png",dpi=300)
plt.savefig("Figures/Teff-Epochs.pdf")

# %%
#Logg
#plot(label, eval_train_logg/eval_train_logg.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_logg/eval_test_logg.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_logg/eval_obs_logg.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_logg/eval_obs2_logg.max(),'k--d',label='Observation',color='k')
plt.xlabel("# Epochs",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$\log g$',  fontsize=15,color='k')
plt.savefig("Figures/Logg-Epochs.png",dpi=300)
plt.savefig("Figures/Logg-Epochs.pdf")

# %%
#vsini
#plot(label, eval_train_vrot/eval_train_vrot.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_vrot/eval_test_vrot.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_vrot/eval_obs_vrot.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_vrot/eval_obs2_vrot.max(),'k--d',label='Observation',color='k')
plt.xlabel("# Epochs",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$v\sin i$',  fontsize=15,color='k')
plt.savefig("Figures/Vrot-Epochs.png",dpi=300)
plt.savefig("Figures/Vrot-Epochs.pdf")

# %%
#Meta
#plot(label, eval_train_meta/eval_train_meta.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_meta/eval_test_meta.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_meta/eval_obs_meta.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_meta/eval_obs2_meta.max(),'k--d',label='Observation',color='k')
plt.xlabel("# Epochs",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '[X/H]',  fontsize=15,color='k')
plt.savefig("Figures/Meta-Epochs.png",dpi=300)
plt.savefig("Figures/Meta-Epochs.pdf")

# %% [markdown]
# # Batches

# %%
data=np.loadtxt("Evaluation/Evaluation_batches-epoch100",dtype=str)
label=data[:,0]
eval_train_teff=np.array(data[:,1]).astype(np.float)
eval_test_teff=np.array(data[:,2]).astype(np.float)
eval_obs_teff=np.array(data[:,3]).astype(np.float)
eval_obs2_teff=np.array(data[:,4]).astype(np.float)
eval_train_logg=np.array(data[:,5]).astype(np.float)
eval_test_logg=np.array(data[:,6]).astype(np.float)
eval_obs_logg=np.array(data[:,7]).astype(np.float)
eval_obs2_logg=np.array(data[:,8]).astype(np.float)
eval_train_vrot=np.array(data[:,9]).astype(np.float)
eval_test_vrot=np.array(data[:,10]).astype(np.float)
eval_obs_vrot=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot=np.array(data[:,12]).astype(np.float)
eval_train_meta=np.array(data[:,13]).astype(np.float)
eval_test_meta=np.array(data[:,14]).astype(np.float)
eval_obs_meta=np.array(data[:,15]).astype(np.float)
eval_obs2_meta=np.array(data[:,16]).astype(np.float)

data=np.loadtxt("Evaluation/Evaluation_batches-epoch500",dtype=str)
eval_train_teff500=np.array(data[:,1]).astype(np.float)
eval_test_teff500=np.array(data[:,2]).astype(np.float)
eval_obs_teff500=np.array(data[:,3]).astype(np.float)
eval_obs2_teff500=np.array(data[:,4]).astype(np.float)
eval_train_logg500=np.array(data[:,5]).astype(np.float)
eval_test_logg500=np.array(data[:,6]).astype(np.float)
eval_obs_logg500=np.array(data[:,7]).astype(np.float)
eval_obs2_logg500=np.array(data[:,8]).astype(np.float)
eval_train_vrot500=np.array(data[:,9]).astype(np.float)
eval_test_vrot500=np.array(data[:,10]).astype(np.float)
eval_obs_vrot500=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot500=np.array(data[:,12]).astype(np.float)
eval_train_meta500=np.array(data[:,13]).astype(np.float)
eval_test_meta500=np.array(data[:,14]).astype(np.float)
eval_obs_meta500=np.array(data[:,15]).astype(np.float)
eval_obs2_meta500=np.array(data[:,16]).astype(np.float)


data=np.loadtxt("Evaluation/Evaluation_batches-epoch1000",dtype=str)
eval_train_teff1000=np.array(data[:,1]).astype(np.float)
eval_test_teff1000=np.array(data[:,2]).astype(np.float)
eval_obs_teff1000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff1000=np.array(data[:,4]).astype(np.float)
eval_train_logg1000=np.array(data[:,5]).astype(np.float)
eval_test_logg1000=np.array(data[:,6]).astype(np.float)
eval_obs_logg1000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg1000=np.array(data[:,8]).astype(np.float)
eval_train_vrot1000=np.array(data[:,9]).astype(np.float)
eval_test_vrot1000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot1000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot1000=np.array(data[:,12]).astype(np.float)
eval_train_meta1000=np.array(data[:,13]).astype(np.float)
eval_test_meta1000=np.array(data[:,14]).astype(np.float)
eval_obs_meta1000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta1000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_batches-epoch2000",dtype=str)
eval_train_teff2000=np.array(data[:,1]).astype(np.float)
eval_test_teff2000=np.array(data[:,2]).astype(np.float)
eval_obs_teff2000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff2000=np.array(data[:,4]).astype(np.float)
eval_train_logg2000=np.array(data[:,5]).astype(np.float)
eval_test_logg2000=np.array(data[:,6]).astype(np.float)
eval_obs_logg2000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg2000=np.array(data[:,8]).astype(np.float)
eval_train_vrot2000=np.array(data[:,9]).astype(np.float)
eval_test_vrot2000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot2000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot2000=np.array(data[:,12]).astype(np.float)
eval_train_meta2000=np.array(data[:,13]).astype(np.float)
eval_test_meta2000=np.array(data[:,14]).astype(np.float)
eval_obs_meta2000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta2000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_batches-epoch3000",dtype=str)
eval_train_teff3000=np.array(data[:,1]).astype(np.float)
eval_test_teff3000=np.array(data[:,2]).astype(np.float)
eval_obs_teff3000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff3000=np.array(data[:,4]).astype(np.float)
eval_train_logg3000=np.array(data[:,5]).astype(np.float)
eval_test_logg3000=np.array(data[:,6]).astype(np.float)
eval_obs_logg3000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg3000=np.array(data[:,8]).astype(np.float)
eval_train_vrot3000=np.array(data[:,9]).astype(np.float)
eval_test_vrot3000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot3000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot3000=np.array(data[:,12]).astype(np.float)
eval_train_meta3000=np.array(data[:,13]).astype(np.float)
eval_test_meta3000=np.array(data[:,14]).astype(np.float)
eval_obs_meta3000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta3000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_batches-epoch4000",dtype=str)
eval_train_teff4000=np.array(data[:,1]).astype(np.float)
eval_test_teff4000=np.array(data[:,2]).astype(np.float)
eval_obs_teff4000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff4000=np.array(data[:,4]).astype(np.float)
eval_train_logg4000=np.array(data[:,5]).astype(np.float)
eval_test_logg4000=np.array(data[:,6]).astype(np.float)
eval_obs_logg4000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg4000=np.array(data[:,8]).astype(np.float)
eval_train_vrot4000=np.array(data[:,9]).astype(np.float)
eval_test_vrot4000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot4000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot4000=np.array(data[:,12]).astype(np.float)
eval_train_meta4000=np.array(data[:,13]).astype(np.float)
eval_test_meta4000=np.array(data[:,14]).astype(np.float)
eval_obs_meta4000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta4000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_batches-epoch5000",dtype=str)
eval_train_teff5000=np.array(data[:,1]).astype(np.float)
eval_test_teff5000=np.array(data[:,2]).astype(np.float)
eval_obs_teff5000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff5000=np.array(data[:,4]).astype(np.float)
eval_train_logg5000=np.array(data[:,5]).astype(np.float)
eval_test_logg5000=np.array(data[:,6]).astype(np.float)
eval_obs_logg5000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg5000=np.array(data[:,8]).astype(np.float)
eval_train_vrot5000=np.array(data[:,9]).astype(np.float)
eval_test_vrot5000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot5000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot5000=np.array(data[:,12]).astype(np.float)
eval_train_meta5000=np.array(data[:,13]).astype(np.float)
eval_test_meta5000=np.array(data[:,14]).astype(np.float)
eval_obs_meta5000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta5000=np.array(data[:,16]).astype(np.float)

Teff=[eval_obs2_teff,eval_obs2_teff500,eval_obs2_teff1000,eval_obs2_teff2000,eval_obs2_teff3000,eval_obs2_teff4000,eval_obs2_teff5000]

logg=[eval_obs2_logg,eval_obs2_logg500,eval_obs2_logg1000,eval_obs2_logg2000,eval_obs2_logg3000,eval_obs2_logg4000,eval_obs2_logg5000]


vrot=[eval_obs2_vrot,eval_obs2_vrot500,eval_obs2_vrot1000,eval_obs2_vrot2000,eval_obs2_vrot3000,eval_obs2_vrot4000,eval_obs2_vrot5000]

meta=[eval_obs2_meta,eval_obs2_meta500,eval_obs2_meta1000,eval_obs2_meta2000,eval_obs2_meta3000,eval_obs2_meta4000,eval_obs2_meta5000]


Teff=np.array(Teff).astype(np.float).max()
logg=np.array(logg).astype(np.float).max()
vrot=np.array(vrot).astype(np.float).max()
meta=np.array(meta).astype(np.float).max()
# Out:
# <ipython-input-126-46d84b301162>:38: UserWarning: loadtxt: Empty input file: "Evaluation_batches-epoch1000"
#   data=np.loadtxt("Evaluation_batches-epoch1000",dtype=str)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-126-46d84b301162> in <module>
#      37
#      38 data=np.loadtxt("Evaluation_batches-epoch1000",dtype=str)
# ---> 39 eval_train_teff1000=np.array(data[:,1]).astype(np.float)
#      40 eval_test_teff1000=np.array(data[:,2]).astype(np.float)
#      41 eval_obs_teff1000=np.array(data[:,3]).astype(np.float)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
#Teff
#plot(label, eval_train_teff/eval_train_teff.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_teff/eval_test_teff.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_teff/eval_obs_teff.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_teff/Teff,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_teff500/Teff,'k--s',label='Observation-500')

plot(label, eval_obs2_teff1000/Teff,'k--^',label='Observation-1000')
plot(label, eval_obs2_teff2000/Teff,'k-->',label='Observation-2000')
plot(label, eval_obs2_teff3000/Teff,'k--<',label='Observation-3000')
plot(label, eval_obs2_teff4000/Teff,'k--*',label='Observation-4000')
plot(label, eval_obs2_teff5000/Teff,'k--x',label='Observation-5000')

plt.xlabel("# Batches",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$T_{eff}$',  fontsize=15,color='k')
plt.savefig("Figures/Teff-Batches.png",dpi=300)
plt.savefig("Figures/Teff-Batches.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-42fc13ec5e5f> in <module>
#       6 plot(label, eval_obs2_teff500/Teff,'k--s',label='Observation-500')
#       7
# ----> 8 plot(label, eval_obs2_teff1000/Teff,'k--^',label='Observation-1000')
#       9 plot(label, eval_obs2_teff2000/Teff,'k-->',label='Observation-2000')
#      10 plot(label, eval_obs2_teff3000/Teff,'k--<',label='Observation-3000')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
#Logg
#plot(label, eval_train_logg/eval_train_logg.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_logg/eval_test_logg.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_logg/eval_obs_logg.max(),'g--o',label='Test',color='g')

plot(label, eval_obs2_logg/logg,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_logg500/logg,'k--s',label='Observation-500')
plot(label, eval_obs2_logg1000/logg,'k--^',label='Observation-1000')
plot(label, eval_obs2_logg2000/logg,'k-->',label='Observation-2000')
plot(label, eval_obs2_logg3000/logg,'k--<',label='Observation-3000')
plot(label, eval_obs2_logg4000/logg,'k--*',label='Observation-4000')
plot(label, eval_obs2_logg5000/logg,'k--x',label='Observation-5000')


plt.xlabel("# Batches",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$\log g$',  fontsize=15,color='k')
plt.savefig("Figures/Logg-Batches.png",dpi=300)
plt.savefig("Figures/Logg-Batches.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-53db8187d13e> in <module>
#       6 plot(label, eval_obs2_logg/logg,'k--o',label='Observation-100',color='k')
#       7 plot(label, eval_obs2_logg500/logg,'k--s',label='Observation-500')
# ----> 8 plot(label, eval_obs2_logg1000/logg,'k--^',label='Observation-1000')
#       9 plot(label, eval_obs2_logg2000/logg,'k-->',label='Observation-2000')
#      10 plot(label, eval_obs2_logg3000/logg,'k--<',label='Observation-3000')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# ...

# %%
#vsini
#plot(label, eval_train_vrot/eval_train_vrot.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_vrot/eval_test_vrot.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_vrot/eval_obs_vrot.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_vrot/vrot,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_vrot500/vrot,'k--s',label='Observation-500')
plot(label, eval_obs2_vrot1000/vrot,'k--^',label='Observation-1000')
plot(label, eval_obs2_vrot2000/vrot,'k-->',label='Observation-2000')
plot(label, eval_obs2_vrot3000/vrot,'k--<',label='Observation-3000')
plot(label, eval_obs2_vrot4000/vrot,'k--*',label='Observation-4000')
plot(label, eval_obs2_vrot5000/vrot,'k--x',label='Observation-5000')


plt.xlabel("# Batches",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$v\sin i$',  fontsize=15,color='k')
plt.savefig("Figures/Vrot-Batches.png",dpi=300)
plt.savefig("Figures/Vrot-Batches.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-0bea9d31156a> in <module>
#       5 plot(label, eval_obs2_vrot/vrot,'k--o',label='Observation-100',color='k')
#       6 plot(label, eval_obs2_vrot500/vrot,'k--s',label='Observation-500')
# ----> 7 plot(label, eval_obs2_vrot1000/vrot,'k--^',label='Observation-1000')
#       8 plot(label, eval_obs2_vrot2000/vrot,'k-->',label='Observation-2000')
#       9 plot(label, eval_obs2_vrot3000/vrot,'k--<',label='Observation-3000')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# ...

# %%
#Meta
#plot(label, eval_train_meta/eval_train_meta.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_meta/eval_test_meta.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_meta/eval_obs_meta.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_meta/meta,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_meta500/meta,'k--s',label='Observation-500')
plot(label, eval_obs2_meta1000/meta,'k--^',label='Observation-1000')
plot(label, eval_obs2_meta2000/meta,'k-->',label='Observation-2000')
plot(label, eval_obs2_meta3000/meta,'k--<',label='Observation-3000')
plot(label, eval_obs2_meta4000/meta,'k--*',label='Observation-4000')
plot(label, eval_obs2_meta5000/meta,'k--x',label='Observation-5000')


plt.xlabel("# Batches",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '[X/H]',  fontsize=15,color='k')
plt.savefig("Figures/Meta-Batches.png",dpi=300)
plt.savefig("Figures/Meta-Batches.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-7f3eab4d7508> in <module>
#       5 plot(label, eval_obs2_meta/meta,'k--o',label='Observation-100',color='k')
#       6 plot(label, eval_obs2_meta500/meta,'k--s',label='Observation-500')
# ----> 7 plot(label, eval_obs2_meta1000/meta,'k--^',label='Observation-1000')
#       8 plot(label, eval_obs2_meta2000/meta,'k-->',label='Observation-2000')
#       9 plot(label, eval_obs2_meta3000/meta,'k--<',label='Observation-3000')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# ...

# %% [markdown]
# # Dropout

# %%
data=np.loadtxt("Evaluation/Evaluation_Dropout-epoch100",dtype=str)
label=data[:,0]
eval_train_teff=np.array(data[:,1]).astype(np.float)
eval_test_teff=np.array(data[:,2]).astype(np.float)
eval_obs_teff=np.array(data[:,3]).astype(np.float)
eval_obs2_teff=np.array(data[:,4]).astype(np.float)
eval_train_logg=np.array(data[:,5]).astype(np.float)
eval_test_logg=np.array(data[:,6]).astype(np.float)
eval_obs_logg=np.array(data[:,7]).astype(np.float)
eval_obs2_logg=np.array(data[:,8]).astype(np.float)
eval_train_vrot=np.array(data[:,9]).astype(np.float)
eval_test_vrot=np.array(data[:,10]).astype(np.float)
eval_obs_vrot=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot=np.array(data[:,12]).astype(np.float)
eval_train_meta=np.array(data[:,13]).astype(np.float)
eval_test_meta=np.array(data[:,14]).astype(np.float)
eval_obs_meta=np.array(data[:,15]).astype(np.float)
eval_obs2_meta=np.array(data[:,16]).astype(np.float)

data=np.loadtxt("Evaluation/Evaluation_Dropout-epoch500",dtype=str)
eval_train_teff500=np.array(data[:,1]).astype(np.float)
eval_test_teff500=np.array(data[:,2]).astype(np.float)
eval_obs_teff500=np.array(data[:,3]).astype(np.float)
eval_obs2_teff500=np.array(data[:,4]).astype(np.float)
eval_train_logg500=np.array(data[:,5]).astype(np.float)
eval_test_logg500=np.array(data[:,6]).astype(np.float)
eval_obs_logg500=np.array(data[:,7]).astype(np.float)
eval_obs2_logg500=np.array(data[:,8]).astype(np.float)
eval_train_vrot500=np.array(data[:,9]).astype(np.float)
eval_test_vrot500=np.array(data[:,10]).astype(np.float)
eval_obs_vrot500=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot500=np.array(data[:,12]).astype(np.float)
eval_train_meta500=np.array(data[:,13]).astype(np.float)
eval_test_meta500=np.array(data[:,14]).astype(np.float)
eval_obs_meta500=np.array(data[:,15]).astype(np.float)
eval_obs2_meta500=np.array(data[:,16]).astype(np.float)

data=np.loadtxt("Evaluation/Evaluation_Dropout-epoch1000",dtype=str)
eval_train_teff1000=np.array(data[:,1]).astype(np.float)
eval_test_teff1000=np.array(data[:,2]).astype(np.float)
eval_obs_teff1000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff1000=np.array(data[:,4]).astype(np.float)
eval_train_logg1000=np.array(data[:,5]).astype(np.float)
eval_test_logg1000=np.array(data[:,6]).astype(np.float)
eval_obs_logg1000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg1000=np.array(data[:,8]).astype(np.float)
eval_train_vrot1000=np.array(data[:,9]).astype(np.float)
eval_test_vrot1000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot1000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot1000=np.array(data[:,12]).astype(np.float)
eval_train_meta1000=np.array(data[:,13]).astype(np.float)
eval_test_meta1000=np.array(data[:,14]).astype(np.float)
eval_obs_meta1000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta1000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_Dropout-epoch2000",dtype=str)
eval_train_teff2000=np.array(data[:,1]).astype(np.float)
eval_test_teff2000=np.array(data[:,2]).astype(np.float)
eval_obs_teff2000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff2000=np.array(data[:,4]).astype(np.float)
eval_train_logg2000=np.array(data[:,5]).astype(np.float)
eval_test_logg2000=np.array(data[:,6]).astype(np.float)
eval_obs_logg2000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg2000=np.array(data[:,8]).astype(np.float)
eval_train_vrot2000=np.array(data[:,9]).astype(np.float)
eval_test_vrot2000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot2000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot2000=np.array(data[:,12]).astype(np.float)
eval_train_meta2000=np.array(data[:,13]).astype(np.float)
eval_test_meta2000=np.array(data[:,14]).astype(np.float)
eval_obs_meta2000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta2000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_Dropout-epoch3000",dtype=str)
eval_train_teff3000=np.array(data[:,1]).astype(np.float)
eval_test_teff3000=np.array(data[:,2]).astype(np.float)
eval_obs_teff3000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff3000=np.array(data[:,4]).astype(np.float)
eval_train_logg3000=np.array(data[:,5]).astype(np.float)
eval_test_logg3000=np.array(data[:,6]).astype(np.float)
eval_obs_logg3000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg3000=np.array(data[:,8]).astype(np.float)
eval_train_vrot3000=np.array(data[:,9]).astype(np.float)
eval_test_vrot3000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot3000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot3000=np.array(data[:,12]).astype(np.float)
eval_train_meta3000=np.array(data[:,13]).astype(np.float)
eval_test_meta3000=np.array(data[:,14]).astype(np.float)
eval_obs_meta3000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta3000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_Dropout-epoch4000",dtype=str)
eval_train_teff4000=np.array(data[:,1]).astype(np.float)
eval_test_teff4000=np.array(data[:,2]).astype(np.float)
eval_obs_teff4000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff4000=np.array(data[:,4]).astype(np.float)
eval_train_logg4000=np.array(data[:,5]).astype(np.float)
eval_test_logg4000=np.array(data[:,6]).astype(np.float)
eval_obs_logg4000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg4000=np.array(data[:,8]).astype(np.float)
eval_train_vrot4000=np.array(data[:,9]).astype(np.float)
eval_test_vrot4000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot4000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot4000=np.array(data[:,12]).astype(np.float)
eval_train_meta4000=np.array(data[:,13]).astype(np.float)
eval_test_meta4000=np.array(data[:,14]).astype(np.float)
eval_obs_meta4000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta4000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_Dropout-epoch5000",dtype=str)
eval_train_teff5000=np.array(data[:,1]).astype(np.float)
eval_test_teff5000=np.array(data[:,2]).astype(np.float)
eval_obs_teff5000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff5000=np.array(data[:,4]).astype(np.float)
eval_train_logg5000=np.array(data[:,5]).astype(np.float)
eval_test_logg5000=np.array(data[:,6]).astype(np.float)
eval_obs_logg5000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg5000=np.array(data[:,8]).astype(np.float)
eval_train_vrot5000=np.array(data[:,9]).astype(np.float)
eval_test_vrot5000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot5000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot5000=np.array(data[:,12]).astype(np.float)
eval_train_meta5000=np.array(data[:,13]).astype(np.float)
eval_test_meta5000=np.array(data[:,14]).astype(np.float)
eval_obs_meta5000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta5000=np.array(data[:,16]).astype(np.float)


Teff=[eval_obs2_teff,eval_obs2_teff500,eval_obs2_teff1000,eval_obs2_teff2000,eval_obs2_teff3000,eval_obs2_teff4000,eval_obs2_teff5000]

logg=[eval_obs2_logg,eval_obs2_logg500,eval_obs2_logg1000,eval_obs2_logg2000,eval_obs2_logg3000,eval_obs2_logg4000,eval_obs2_logg5000]


vrot=[eval_obs2_vrot,eval_obs2_vrot500,eval_obs2_vrot1000,eval_obs2_vrot2000,eval_obs2_vrot3000,eval_obs2_vrot4000,eval_obs2_vrot5000]

meta=[eval_obs2_meta,eval_obs2_meta500,eval_obs2_meta1000,eval_obs2_meta2000,eval_obs2_meta3000,eval_obs2_meta4000,eval_obs2_meta5000]


Teff=np.array(Teff).astype(np.float).max()
logg=np.array(logg).astype(np.float).max()
vrot=np.array(vrot).astype(np.float).max()
meta=np.array(meta).astype(np.float).max()

# %%
#Teff
#plot(label, eval_train_teff/eval_train_teff.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_teff/eval_test_teff.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_teff/eval_obs_teff.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_teff/Teff,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_teff500/Teff,'k--s',label='Observation-500')

plot(label, eval_obs2_teff1000/Teff,'k--^',label='Observation-1000')
plot(label, eval_obs2_teff2000/Teff,'k-->',label='Observation-2000')
plot(label, eval_obs2_teff3000/Teff,'k--<',label='Observation-3000')
plot(label, eval_obs2_teff4000/Teff,'k--*',label='Observation-4000')
plot(label, eval_obs2_teff5000/Teff,'k--x',label='Observation-5000')

plt.xlabel("Dropout",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$T_{eff}$',  fontsize=15,color='k')
plt.savefig("Figures/Teff-Dropout.png",dpi=300)
plt.savefig("Figures/Teff-Dropout.pdf")

# %%
#Logg
#plot(label, eval_train_logg/eval_train_logg.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_logg/eval_test_logg.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_logg/eval_obs_logg.max(),'g--o',label='Test',color='g')

plot(label, eval_obs2_logg/logg,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_logg500/logg,'k--s',label='Observation-500')
plot(label, eval_obs2_logg1000/logg,'k--^',label='Observation-1000')
plot(label, eval_obs2_logg2000/logg,'k-->',label='Observation-2000')
plot(label, eval_obs2_logg3000/logg,'k--<',label='Observation-3000')
plot(label, eval_obs2_logg4000/logg,'k--*',label='Observation-4000')
plot(label, eval_obs2_logg5000/logg,'k--x',label='Observation-5000')


plt.xlabel("Dropout",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$\log g$',  fontsize=15,color='k')
plt.savefig("Figures/Logg-Dropout.png",dpi=300)
plt.savefig("Figures/Logg-Dropout.pdf")

# %%
#vsini
#plot(label, eval_train_vrot/eval_train_vrot.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_vrot/eval_test_vrot.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_vrot/eval_obs_vrot.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_vrot/vrot,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_vrot500/vrot,'k--s',label='Observation-500')
plot(label, eval_obs2_vrot1000/vrot,'k--^',label='Observation-1000')
plot(label, eval_obs2_vrot2000/vrot,'k-->',label='Observation-2000')
plot(label, eval_obs2_vrot3000/vrot,'k--<',label='Observation-3000')
plot(label, eval_obs2_vrot4000/vrot,'k--*',label='Observation-4000')
plot(label, eval_obs2_vrot5000/vrot,'k--x',label='Observation-5000')

plt.xlabel("Dropout",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$v\sin i$',  fontsize=15,color='k')
plt.savefig("Figures/Vrot-Dropout.png",dpi=300)
plt.savefig("Figures/Vrot-Dropout.pdf")

# %%
#Meta
#plot(label, eval_train_meta/eval_train_meta.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_meta/eval_test_meta.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_meta/eval_obs_meta.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_meta/meta,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_meta500/meta,'k--s',label='Observation-500')
plot(label, eval_obs2_meta1000/meta,'k--^',label='Observation-1000')
plot(label, eval_obs2_meta2000/meta,'k-->',label='Observation-2000')
plot(label, eval_obs2_meta3000/meta,'k--<',label='Observation-3000')
plot(label, eval_obs2_meta4000/meta,'k--*',label='Observation-4000')
plot(label, eval_obs2_meta5000/meta,'k--x',label='Observation-5000')


plt.xlabel("Dropout",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '[X/H]',  fontsize=15,color='k')
plt.savefig("Figures/Meta-Dropout.png",dpi=300)
plt.savefig("Figures/Meta-Dropout.pdf")

# %% [markdown]
# # Loss

# %%
data=np.loadtxt("Evaluation/Evaluation_Loss-epoch100",dtype=str)
label=data[:,0]
eval_train_teff=np.array(data[:,1]).astype(np.float)
eval_test_teff=np.array(data[:,2]).astype(np.float)
eval_obs_teff=np.array(data[:,3]).astype(np.float)
eval_obs2_teff=np.array(data[:,4]).astype(np.float)
eval_train_logg=np.array(data[:,5]).astype(np.float)
eval_test_logg=np.array(data[:,6]).astype(np.float)
eval_obs_logg=np.array(data[:,7]).astype(np.float)
eval_obs2_logg=np.array(data[:,8]).astype(np.float)
eval_train_vrot=np.array(data[:,9]).astype(np.float)
eval_test_vrot=np.array(data[:,10]).astype(np.float)
eval_obs_vrot=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot=np.array(data[:,12]).astype(np.float)
eval_train_meta=np.array(data[:,13]).astype(np.float)
eval_test_meta=np.array(data[:,14]).astype(np.float)
eval_obs_meta=np.array(data[:,15]).astype(np.float)
eval_obs2_meta=np.array(data[:,16]).astype(np.float)

data=np.loadtxt("Evaluation/Evaluation_Loss-epoch500",dtype=str)
eval_train_teff500=np.array(data[:,1]).astype(np.float)
eval_test_teff500=np.array(data[:,2]).astype(np.float)
eval_obs_teff500=np.array(data[:,3]).astype(np.float)
eval_obs2_teff500=np.array(data[:,4]).astype(np.float)
eval_train_logg500=np.array(data[:,5]).astype(np.float)
eval_test_logg500=np.array(data[:,6]).astype(np.float)
eval_obs_logg500=np.array(data[:,7]).astype(np.float)
eval_obs2_logg500=np.array(data[:,8]).astype(np.float)
eval_train_vrot500=np.array(data[:,9]).astype(np.float)
eval_test_vrot500=np.array(data[:,10]).astype(np.float)
eval_obs_vrot500=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot500=np.array(data[:,12]).astype(np.float)
eval_train_meta500=np.array(data[:,13]).astype(np.float)
eval_test_meta500=np.array(data[:,14]).astype(np.float)
eval_obs_meta500=np.array(data[:,15]).astype(np.float)
eval_obs2_meta500=np.array(data[:,16]).astype(np.float)

data=np.loadtxt("Evaluation/Evaluation_Loss-epoch1000",dtype=str)
eval_train_teff1000=np.array(data[:,1]).astype(np.float)
eval_test_teff1000=np.array(data[:,2]).astype(np.float)
eval_obs_teff1000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff1000=np.array(data[:,4]).astype(np.float)
eval_train_logg1000=np.array(data[:,5]).astype(np.float)
eval_test_logg1000=np.array(data[:,6]).astype(np.float)
eval_obs_logg1000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg1000=np.array(data[:,8]).astype(np.float)
eval_train_vrot1000=np.array(data[:,9]).astype(np.float)
eval_test_vrot1000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot1000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot1000=np.array(data[:,12]).astype(np.float)
eval_train_meta1000=np.array(data[:,13]).astype(np.float)
eval_test_meta1000=np.array(data[:,14]).astype(np.float)
eval_obs_meta1000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta1000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_Loss-epoch2000",dtype=str)
eval_train_teff2000=np.array(data[:,1]).astype(np.float)
eval_test_teff2000=np.array(data[:,2]).astype(np.float)
eval_obs_teff2000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff2000=np.array(data[:,4]).astype(np.float)
eval_train_logg2000=np.array(data[:,5]).astype(np.float)
eval_test_logg2000=np.array(data[:,6]).astype(np.float)
eval_obs_logg2000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg2000=np.array(data[:,8]).astype(np.float)
eval_train_vrot2000=np.array(data[:,9]).astype(np.float)
eval_test_vrot2000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot2000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot2000=np.array(data[:,12]).astype(np.float)
eval_train_meta2000=np.array(data[:,13]).astype(np.float)
eval_test_meta2000=np.array(data[:,14]).astype(np.float)
eval_obs_meta2000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta2000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_Loss-epoch3000",dtype=str)
eval_train_teff3000=np.array(data[:,1]).astype(np.float)
eval_test_teff3000=np.array(data[:,2]).astype(np.float)
eval_obs_teff3000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff3000=np.array(data[:,4]).astype(np.float)
eval_train_logg3000=np.array(data[:,5]).astype(np.float)
eval_test_logg3000=np.array(data[:,6]).astype(np.float)
eval_obs_logg3000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg3000=np.array(data[:,8]).astype(np.float)
eval_train_vrot3000=np.array(data[:,9]).astype(np.float)
eval_test_vrot3000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot3000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot3000=np.array(data[:,12]).astype(np.float)
eval_train_meta3000=np.array(data[:,13]).astype(np.float)
eval_test_meta3000=np.array(data[:,14]).astype(np.float)
eval_obs_meta3000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta3000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_Loss-epoch4000",dtype=str)
eval_train_teff4000=np.array(data[:,1]).astype(np.float)
eval_test_teff4000=np.array(data[:,2]).astype(np.float)
eval_obs_teff4000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff4000=np.array(data[:,4]).astype(np.float)
eval_train_logg4000=np.array(data[:,5]).astype(np.float)
eval_test_logg4000=np.array(data[:,6]).astype(np.float)
eval_obs_logg4000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg4000=np.array(data[:,8]).astype(np.float)
eval_train_vrot4000=np.array(data[:,9]).astype(np.float)
eval_test_vrot4000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot4000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot4000=np.array(data[:,12]).astype(np.float)
eval_train_meta4000=np.array(data[:,13]).astype(np.float)
eval_test_meta4000=np.array(data[:,14]).astype(np.float)
eval_obs_meta4000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta4000=np.array(data[:,16]).astype(np.float)



data=np.loadtxt("Evaluation/Evaluation_Loss-epoch5000",dtype=str)
eval_train_teff5000=np.array(data[:,1]).astype(np.float)
eval_test_teff5000=np.array(data[:,2]).astype(np.float)
eval_obs_teff5000=np.array(data[:,3]).astype(np.float)
eval_obs2_teff5000=np.array(data[:,4]).astype(np.float)
eval_train_logg5000=np.array(data[:,5]).astype(np.float)
eval_test_logg5000=np.array(data[:,6]).astype(np.float)
eval_obs_logg5000=np.array(data[:,7]).astype(np.float)
eval_obs2_logg5000=np.array(data[:,8]).astype(np.float)
eval_train_vrot5000=np.array(data[:,9]).astype(np.float)
eval_test_vrot5000=np.array(data[:,10]).astype(np.float)
eval_obs_vrot5000=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot5000=np.array(data[:,12]).astype(np.float)
eval_train_meta5000=np.array(data[:,13]).astype(np.float)
eval_test_meta5000=np.array(data[:,14]).astype(np.float)
eval_obs_meta5000=np.array(data[:,15]).astype(np.float)
eval_obs2_meta5000=np.array(data[:,16]).astype(np.float)


Teff=[eval_obs2_teff,eval_obs2_teff500,eval_obs2_teff1000,eval_obs2_teff2000,eval_obs2_teff3000,eval_obs2_teff4000,eval_obs2_teff5000]

logg=[eval_obs2_logg,eval_obs2_logg500,eval_obs2_logg1000,eval_obs2_logg2000,eval_obs2_logg3000,eval_obs2_logg4000,eval_obs2_logg5000]


vrot=[eval_obs2_vrot,eval_obs2_vrot500,eval_obs2_vrot1000,eval_obs2_vrot2000,eval_obs2_vrot3000,eval_obs2_vrot4000,eval_obs2_vrot5000]

meta=[eval_obs2_meta,eval_obs2_meta500,eval_obs2_meta1000,eval_obs2_meta2000,eval_obs2_meta3000,eval_obs2_meta4000,eval_obs2_meta5000]


Teff=np.array(Teff).astype(np.float).max()
logg=np.array(logg).astype(np.float).max()
vrot=np.array(vrot).astype(np.float).max()
meta=np.array(meta).astype(np.float).max()

# %%
#Teff
#plot(label, eval_train_teff/eval_train_teff.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_teff/eval_test_teff.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_teff/eval_obs_teff.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_teff/Teff,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_teff500/Teff,'k--s',label='Observation-500')

plot(label, eval_obs2_teff1000/Teff,'k--^',label='Observation-1000')
plot(label, eval_obs2_teff2000/Teff,'k-->',label='Observation-2000')
plot(label, eval_obs2_teff3000/Teff,'k--<',label='Observation-3000')
plot(label, eval_obs2_teff4000/Teff,'k--*',label='Observation-4000')
plot(label, eval_obs2_teff5000/Teff,'k--x',label='Observation-5000')


plt.xlabel("Loss Function",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$T_{eff}$',  fontsize=15,color='k')
plt.savefig("Figures/Teff-Loss.png",dpi=300)
plt.savefig("Figures/Teff-Loss.pdf")

# %%
#Logg
#plot(label, eval_train_logg/eval_train_logg.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_logg/eval_test_logg.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_logg/eval_obs_logg.max(),'g--o',label='Test',color='g')

plot(label, eval_obs2_logg/logg,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_logg500/logg,'k--s',label='Observation-500')
plot(label, eval_obs2_logg1000/logg,'k--^',label='Observation-1000')
plot(label, eval_obs2_logg2000/logg,'k-->',label='Observation-2000')
plot(label, eval_obs2_logg3000/logg,'k--<',label='Observation-3000')
plot(label, eval_obs2_logg4000/logg,'k--*',label='Observation-4000')
plot(label, eval_obs2_logg5000/logg,'k--x',label='Observation-5000')


plt.xlabel("Loss Function",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$\log g$',  fontsize=15,color='k')
plt.savefig("Figures/Logg-Loss.png",dpi=300)
plt.savefig("Figures/Logg-Loss.pdf")

# %%
#vsini
#plot(label, eval_train_vrot/eval_train_vrot.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_vrot/eval_test_vrot.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_vrot/eval_obs_vrot.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_vrot/vrot,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_vrot500/vrot,'k--s',label='Observation-500')
plot(label, eval_obs2_vrot1000/vrot,'k--^',label='Observation-1000')
plot(label, eval_obs2_vrot2000/vrot,'k-->',label='Observation-2000')
plot(label, eval_obs2_vrot3000/vrot,'k--<',label='Observation-3000')
plot(label, eval_obs2_vrot4000/vrot,'k--*',label='Observation-4000')
plot(label, eval_obs2_vrot5000/vrot,'k--x',label='Observation-5000')

plt.xlabel("Loss Function",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '$v\sin i$',  fontsize=15,color='k')
plt.savefig("Figures/Vrot-Loss.png",dpi=300)
plt.savefig("Figures/Vrot-Loss.pdf")

# %%
#Meta
#plot(label, eval_train_meta/eval_train_meta.max(),'r-o',label='Training',color='r')
#plot(label, eval_test_meta/eval_test_meta.max(),'b--o',label='Validation',color='b')
#plot(label, eval_obs_meta/eval_obs_meta.max(),'g--o',label='Test',color='g')
plot(label, eval_obs2_meta/meta,'k--o',label='Observation-100',color='k')
plot(label, eval_obs2_meta500/meta,'k--s',label='Observation-500')
plot(label, eval_obs2_meta1000/meta,'k--^',label='Observation-1000')
plot(label, eval_obs2_meta2000/meta,'k-->',label='Observation-2000')
plot(label, eval_obs2_meta3000/meta,'k--<',label='Observation-3000')
plot(label, eval_obs2_meta4000/meta,'k--*',label='Observation-4000')
plot(label, eval_obs2_meta5000/meta,'k--x',label='Observation-5000')


plt.xlabel("Loss Function",fontsize=14)
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
#plt.text(0.3, 0.95, '[X/H]',  fontsize=15,color='k')
plt.savefig("Figures/Meta-Loss.png",dpi=300)
plt.savefig("Figures/Meta-Loss.pdf")

# %% [markdown]
# ## Plotting Random spectra of the Database

# %%
Dumpfiles=["Database/Dumpfile-4450-4990-7000-10000-200-2-5-0.5-vsini-0-300-met-0-Vmicr2-Resolution60000",\
           "Database/Dumpfile-Random-lambda4450.00-4989.95-teff7000.0-11000.0-logg2.00-5.00-vsini0-300-meta0-Vmicr2-Resolution60000",\
           "Database/Dumpfile-Random-medium-lambda4450.00-4989.95-teff7000.0-11000.0-logg2.00-5.00-vsini0-300-meta0-Vmicr2-Resolution60000",\
           "Database/Dumpfile-random-meta-22000spectrum",\
           "Database/Dumpfile-random-meta-37500spectrum",\
           "Database/Dumpfile-random-meta-62000spectrum",\
           "Database/Dumpfile-Random-small-lambda4450.00-4989.95-teff7000.0-11000.0-logg2.00-5.00-vsini0-300-meta0-Vmicr2-Resolution60000",\
           "Database/Dumpfile-lambda4450.00-4989.95-teff7000.0-11000.0-100-logg2.00-5.00-0.20-vsini0-300-meta0.00-0.00-0.50-Vmicr2.00-2.00-1.00-Resolution60000",\
           "Database/Dumpfile-lambda4450.00-4989.95-teff7000.0-11000.0-100-logg2.00-5.00-0.10-vsini0-300-meta0.00-0.00-0.50-Vmicr2.00-2.00-1.00-Resolution60000",\
           "Database/Dumpfile-lambda4450.00-4989.95-teff7000.0-11000.0-100-logg2.00-5.00-0.10-vsini0-300-meta0.00-0.00-0.50-Vmicr2.00-2.00-1.00-Resolution100000",\
           "Database/Dumpfile-lambda4450.00-4989.95-teff7000.0-11000.0-100-logg2.00-5.00-0.10-vsini0-300-meta0.00-0.00-0.50-Vmicr2.00-2.00-1.00-Resolution25000",\
           "Database/Dumpfile-lambda4450.00-4989.95-teff7000.0-11000.0-500-logg2.00-5.00-0.50-vsini0-300-meta-1.50-1.50-0.50-Vmicr2.00-2.00-1.00-Resolution60000"]
Dump=Dumpfiles[3]
lamb=np.arange(4450.,4990,0.05)
print(Dump)
temp=np.loadtxt("Template/atSS02997-t009000g4.00-vrot000res060000-met+0.0-micr2.0s48.dat")
# Normal Data
grid=pd.read_pickle(Dump)
nmod=len(grid) # Number of spectra in learning database
nwav=len(grid[0][0]) # Numer of data point in each spectra
mat=np.zeros((len(grid), nwav), 'Float32') # nmod by nmwav matrix of learning database matrix
teff=[] # Teff of each spectrum
logg=[] # logg of each spectrum
vrot=[] # vrot of each spectrum
metal=[] # vrot of each spectrum
SN=[]# Vmicr of each spectrum

for i in np.arange(nmod):
    mat[i,:]=grid[i][0]
    teff.append(grid[i][1])
    logg.append(grid[i][2])
    vrot.append(grid[i][3])
    metal.append(grid[i][4])
    #SN.append(grid[i][5])
   # micro.append(grid[i][5])
    if (i % 2000==0):
        print('Progress report', i,"th spectrum")
# Out:
# Database/Dumpfile-random-meta-22000spectrum
# <ipython-input-2-28c1f19d4819>:21: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   mat=np.zeros((len(grid), nwav), 'Float32') # nmod by nmwav matrix of learning database matrix
# Progress report 0 th spectrum
# Progress report 2000 th spectrum
# Progress report 4000 th spectrum
# Progress report 6000 th spectrum
# Progress report 8000 th spectrum
# Progress report 10000 th spectrum
# Progress report 12000 th spectrum
# Progress report 14000 th spectrum
# Progress report 16000 th spectrum
# Progress report 18000 th spectrum
# Progress report 20000 th spectrum
# Progress report 22000 th spectrum

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(18, 5),sharex=True)
fig.subplots_adjust(hspace=0)

#xlabel('Wavelength')
#ylabel('Normalized Flux')
i=3000
ax[0].plot(lamb,mat[i,:],'k')

ax[1].plot(lamb,mat[i+int(nmod/6),:],'k')
ax[2].plot(lamb,mat[i+2*int(nmod/6),:],'k')
#ax[1,0].plot(lamb,mat[i+3*int(nmod/6),:],'k')
#ax[1,1].plot(lamb,mat[i+4*int(nmod/6),:],'k')
#ax[1,2].plot(lamb,mat[i+5*int(nmod/6),:],'k')
fig.text(0.5, -0.02, 'Wavelength', ha='center',fontsize=15)
fig.text(0.08, 0.5, 'Normalized Flux', va='center', rotation='vertical',fontsize=15)
#fig.tight_layout()
plt.savefig("Figures/Spectra_sample.pdf")

plt.show()

#print(teff[i],'K,', logg[i],'dex,', vrot[i], 'Km/s,','0.0', 'dex')

# %% [markdown]
# # Data big Small - Augmentation

# %%
data=np.loadtxt("Evaluation/Big-Small-augmentation",dtype=str)
label=data[:,0]
eval_train_teff=np.array(data[:,1]).astype(np.float)
eval_test_teff=np.array(data[:,2]).astype(np.float)
eval_obs_teff=np.array(data[:,3]).astype(np.float)
eval_obs2_teff=np.array(data[:,4]).astype(np.float)
eval_train_logg=np.array(data[:,5]).astype(np.float)
eval_test_logg=np.array(data[:,6]).astype(np.float)
eval_obs_logg=np.array(data[:,7]).astype(np.float)
eval_obs2_logg=np.array(data[:,8]).astype(np.float)
eval_train_vrot=np.array(data[:,9]).astype(np.float)
eval_test_vrot=np.array(data[:,10]).astype(np.float)
eval_obs_vrot=np.array(data[:,11]).astype(np.float)
eval_obs2_vrot=np.array(data[:,12]).astype(np.float)
eval_train_meta=np.array(data[:,13]).astype(np.float)
eval_test_meta=np.array(data[:,14]).astype(np.float)
eval_obs_meta=np.array(data[:,15]).astype(np.float)
eval_obs2_meta=np.array(data[:,16]).astype(np.float)

# %%
#Teff
plot(label, eval_train_teff/eval_train_teff.max(),'k--^',label='Training')
plot(label, eval_test_teff/eval_test_teff.max(),'k--s',label='Validation')
plot(label, eval_obs_teff/eval_obs_teff.max(),'k-->',label='Test')
plot(label, eval_obs2_teff/eval_obs2_teff.max(),'k--o',label='Observation')

plt.xlabel("")
plt.ylabel("Relative error w.r.t Max",fontsize=14)
plt.legend()
plt.text(0.3, 0.85, '$T_{eff}$',  fontsize=15,color='k')
plt.savefig("Figures/Teff-big-small-aug.png",dpi=300)
plt.savefig("Figures/Teff-big-small-aug.pdf")

# %%
#Logg
plot(label, eval_train_logg/eval_train_logg.max(),'k--^',label='Training')
plot(label, eval_test_logg/eval_test_logg.max(),'k--s',label='Validation')
plot(label, eval_obs_logg/eval_obs_logg.max(),'k-->',label='Test')

plot(label, eval_obs2_logg/eval_obs2_logg.max(),'k--o',label='Observation')


plt.xlabel("")
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
plt.text(0.3, 0.95, '$\log g$',  fontsize=15,color='k')
plt.savefig("Figures/Logg-big-small-aug.png",dpi=300)
plt.savefig("Figures/Logg-big-small-aug.pdf")

# %%
#vsini
plot(label, eval_train_vrot/eval_train_vrot.max(),'k--^',label='Training')
plot(label, eval_test_vrot/eval_test_vrot.max(),'k--s',label='Validation')
plot(label, eval_obs_vrot/eval_obs_vrot.max(),'k-->',label='Test')
plot(label, eval_obs2_vrot/eval_obs2_vrot.max(),'k--o',label='Observation')


plt.xlabel("")
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
plt.text(0.3, 0.98, '$v\sin i$',  fontsize=15,color='k')
plt.savefig("Figures/Vrot-big-small-aug.png",dpi=300)
plt.savefig("Figures/Vrot-big-small-aug.pdf")

# %%
#Meta
plot(label, eval_train_meta/eval_train_meta.max(),'k--^',label='Training')
plot(label, eval_test_meta/eval_test_meta.max(),'k--s',label='Validation')
plot(label, eval_obs_meta/eval_obs_meta.max(),'k-->',label='Test')
plot(label, eval_obs2_meta/eval_obs2_meta.max(),'k--o',label='Observation')


plt.xlabel("")
plt.ylabel("Relative error w.r.t Max",fontsize=14)
#plt.legend()
plt.text(0.3, 0.95, '[X/H]',  fontsize=15,color='k')
plt.savefig("Figures/Meta-big-small-aug.png",dpi=300)
plt.savefig("Figures/Meta-big-small-aug.pdf")

# %%
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(8, 18),sharex=True)
fig.subplots_adjust(hspace=0)

#xlabel('Wavelength')
#ylabel('Normalized Flux')

ax[0].plot(label, eval_train_teff/eval_train_teff.max(),'k--^',label='Training')
ax[0].plot(label, eval_test_teff/eval_test_teff.max(),'k--s',label='Validation')
ax[0].plot(label, eval_obs_teff/eval_obs_teff.max(),'k-->',label='Test')
ax[0].plot(label, eval_obs2_teff/eval_obs2_teff.max(),'k--o',label='Observation')
plt.text(0.3, 2, '$T_{eff}$',  fontsize=15,color='k')

ax[0].legend()


ax[1].plot(label, eval_train_logg/eval_train_logg.max(),'k--^')
ax[1].plot(label, eval_test_logg/eval_test_logg.max(),'k--s')
ax[1].plot(label, eval_obs_logg/eval_obs_logg.max(),'k-->')
ax[1].plot(label, eval_obs2_logg/eval_obs2_logg.max(),'k--o')
plt.text(0.3, 1.6, '$\log g$',  fontsize=15,color='k')

ax[2].plot(label, eval_train_vrot/eval_train_vrot.max(),'k--^',label='')
ax[2].plot(label, eval_test_vrot/eval_test_vrot.max(),'k--s',label='')
ax[2].plot(label, eval_obs_vrot/eval_obs_vrot.max(),'k-->',label='')
ax[2].plot(label, eval_obs2_vrot/eval_obs2_vrot.max(),'k--o',label='')
plt.text(0.3, 1.1, '$v\sin i$',  fontsize=15,color='k')


ax[3].plot(label, eval_train_meta/eval_train_meta.max(),'k--^',label='')
ax[3].plot(label, eval_test_meta/eval_test_meta.max(),'k--s',label='')
ax[3].plot(label, eval_obs_meta/eval_obs_meta.max(),'k-->',label='')
ax[3].plot(label, eval_obs2_meta/eval_obs2_meta.max(),'k--o',label='')
plt.text(0.3, 0.7, '[X/H]',  fontsize=15,color='k')



#fig.text(0.5, -0.02, 'Wavelength', ha='center',fontsize=15)
fig.text(0.01, 0.5, "Relative error w.r.t Max", va='center', rotation='vertical',fontsize=20)
#fig.tight_layout()

plt.savefig("Figures/all-big-small-aug.png",dpi=300)
plt.savefig("Figures/all-big-small-aug.pdf")
